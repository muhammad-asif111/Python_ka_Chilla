# %% [markdown]
# ### How to import dataset in python using pandas library
# Written By: Dr Muhammad Asif Assistant\
# Email: asifbwp78654@gmail.com\
# Date:17-01-22

# %%
# Step -1
# importing libraries
import pandas as pd

# %%
##### Practice How to import dataset in python using pandas
# Step-2 
# reading / importing dataset with name
df = pd.read_excel("pandas_01_day6.xlsx")  # write the path if you want to load the data from day_1 to day_6

# %%
df
# Out:
#    height  weight favourite_dish
# 0     5.8     101  Chicken Pulao
# 1     6.2      92        Biryani
# 2     5.9      62  Karahi Ghosht
# 3     5.9      95  Chicken Pulao
# 4     5.9      55  Chicken Pulao
# ..    ...     ...            ...
# 82    5.4      55          Pasta
# 83    5.9      75  Karahi Ghosht
# 84    5.4      61        Biryani
# 85    6.2      68  Chicken Pulao
# 86    5.1      96        Biryani
#
# [87 rows x 3 columns]

# %%
print(df)
# Out:
#    height  weight favourite_dish
# 0     5.8     101  Chicken Pulao
# 1     6.2      92        Biryani
# 2     5.9      62  Karahi Ghosht
# 3     5.9      95  Chicken Pulao
# 4     5.9      55  Chicken Pulao
# ..    ...     ...            ...
# 82    5.4      55          Pasta
# 83    5.9      75  Karahi Ghosht
# 84    5.4      61        Biryani
# 85    6.2      68  Chicken Pulao
# 86    5.1      96        Biryani
#
# [87 rows x 3 columns]

# %%
df.head()
# Out:
#   height  weight favourite_dish
# 0    5.8     101  Chicken Pulao
# 1    6.2      92        Biryani
# 2    5.9      62  Karahi Ghosht
# 3    5.9      95  Chicken Pulao
# 4    5.9      55  Chicken Pulao

# %%
df.tail()
# Out:
#    height  weight favourite_dish
# 82    5.4      55          Pasta
# 83    5.9      75  Karahi Ghosht
# 84    5.4      61        Biryani
# 85    6.2      68  Chicken Pulao
# 86    5.1      96        Biryani

# %%
# Take Transpose
df.T
# Out:
#                            0        1              2              3   \
# height                    5.8      6.2            5.9            5.9
# weight                    101       92             62             95
# favourite_dish  Chicken Pulao  Biryani  Karahi Ghosht  Chicken Pulao
#
#                            4        5      6        7        8        9   ...  \
# height                    5.9      5.3    5.6      5.9      5.1      5.4  ...
# weight                     55       59     50       76       78       68  ...
# favourite_dish  Chicken Pulao  Biryani  Pasta  Biryani  Biryani  Biryani  ...
#
#                      77             78       79     80             81     82  \
# height              5.5           5.11      5.3    5.4            5.5    5.4
# weight               85             72       62     55             52     55
# favourite_dish  Biryani  Karahi Ghosht  Biryani  Pasta  Karahi Ghosht  Pasta
#
#                            83       84             85       86
# ...

# %%
df.shape
# Out:
# (87, 3)

# %%
df.head(12)
# Out:
#    height  weight favourite_dish
# 0     5.8     101  Chicken Pulao
# 1     6.2      92        Biryani
# 2     5.9      62  Karahi Ghosht
# 3     5.9      95  Chicken Pulao
# 4     5.9      55  Chicken Pulao
# 5     5.3      59        Biryani
# 6     5.6      50          Pasta
# 7     5.9      76        Biryani
# 8     5.1      78        Biryani
# 9     5.4      68        Biryani
# 10   5.11      92  Karahi Ghosht
# 11    5.7      73        Biryani

# %%
# df.info() # Functions 
df.info()       # Type Casting due to weight column (KG)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   height          87 non-null     object
#  1   weight          87 non-null     int64
#  2   favourite_dish  87 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 2.2+ KB
