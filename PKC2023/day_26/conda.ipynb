# %% [markdown]
# # Conda Environments
#     # Written By:     Dr Muhammad Asif Assistant
#
#     # Email:          asifbwp78654@gmail.com
#
#     # Date:           28-09-23

# %% [markdown]
# conda env list
# conda list
# conda info
# conda update conda
# conda install python
# conda install spyder
# conda update python
# conda update --help
# conda env list
# conda crete -n pandas_env
# conda activatre pandas_env
# conda install python
# pip install pandas
# pip install pandas numpy matplotlib seaborn scipy scikit-learn
# conda create --clone pandas_env --name pandas_env2
# cd desktop
# dir
# make dir
# cd conda
# conda list --explicit > pandas_env.txt
# # After Text file use to crete environments
# conda install -yes --file requirements.txt      # install complete file
# pip install -r requirements.txt
# deactivate
# conda env list
# conda create --file requirements.txt
# conda create -n bio_env biopython
# # Search Package
# conda search python
# conda search r
# conda install python=3.10.4
# ctrl+ \   stop
# ctrl+ c   stop
# conda create -n jupyter-nb jupyter
# conda activate jupyter-nb
# conda list
# jupyter-notebook
# conda deactivate
# conda env remove -n pandas_env2 bio_env
# conda remove --name base spyder
#
# # versions
# conda create -n py34 python=3.4
# # add channels
# conda create -n py34
# conda activate py34
# conda install --channel conda-forge python =3.4
# conda install python=3.7 --channel conda -forge --channel bioconda
# # Rename
# conda deactivate
# conda env list
# conda create --name py37 --copy --clone py34
# conda env list
# conda env remove -n py34
# conda env list
# where python
# python --version
# conda activate pandas_env
# python version
# where python
# pip install numpy == 1.11
# conda list
# conda search pandas
# pip install pandas == 1.3.5
# conda remove --name pandas_env python
# conda env remove -n tf_env
#
# # How to create python virtual environmet
#
# # 2
# conda create -n tf_env
# conda env list
# conda activate tf_env
# conda install python=3.9
# conda list
# nvidia -smi
# conda
# pip install --upgrade pip
# conda update conda
# pip install tensorflow
# python -c "import tensorflow as tf; print(tf.reduce_sum(tf.random.normal([1000, 1000])))"
# conda list
#
# pip install pandas numpy seaborn matplotlib plotly openpyxl stremlit scikit-learn jupyuter
