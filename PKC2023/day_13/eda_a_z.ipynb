# %% [markdown]
# # EDA : Exploratory Data Analysis
# By    : Dr Muhammad Asif Assistant\
# Email : asifbwp78654@gmail.com\
# Date  : 03-02-23

# %% [markdown]
# Method Analyzed & Summarize Datasets using Pandas

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset("titanic")

# %% [markdown]
# # Analyzed

# %%
df.head()
df.tail()
df.info()
df.shape
df.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB
# survived          int64
# pclass            int64
# ...

# %% [markdown]
# # Summarize Statistics

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.isnull()
# Out:
#      survived  pclass    sex    age  sibsp  parch   fare  embarked  class  \
# 0       False   False  False  False  False  False  False     False  False
# 1       False   False  False  False  False  False  False     False  False
# 2       False   False  False  False  False  False  False     False  False
# 3       False   False  False  False  False  False  False     False  False
# 4       False   False  False  False  False  False  False     False  False
# ..        ...     ...    ...    ...    ...    ...    ...       ...    ...
# 886     False   False  False  False  False  False  False     False  False
# 887     False   False  False  False  False  False  False     False  False
# 888     False   False  False   True  False  False  False     False  False
# 889     False   False  False  False  False  False  False     False  False
# 890     False   False  False  False  False  False  False     False  False
#
#        who  adult_male   deck  embark_town  alive  alone
# ...

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# # Average

# %%
df.isnull().sum() * 100 /len(df)
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %% [markdown]
# # Find Unique Values

# %%
df.nunique()
# Out:
# survived         2
# pclass           3
# sex              2
# age             88
# sibsp            7
# parch            7
# fare           248
# embarked         3
# class            3
# who              3
# adult_male       2
# deck             7
# embark_town      3
# alive            2
# alone            2
# dtype: int64

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %% [markdown]
# # Visualize the nan values in heatmap

# %%
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Removal of deck column

# %%
df.drop(columns="deck", inplace=True)

# %%
df.columns
df.shape
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  embark_town  889 non-null    object
#  12  alive        891 non-null    object
#  13  alone        891 non-null    bool
# dtypes: bool(2), category(1), float64(2), int64(4), object(5)
# memory usage: 79.4+ KB

# %% [markdown]
# # Visualize and Explore

# %%
sns.countplot(data=df,x="survived") # Only for Categorical Variable
# Out:
# <AxesSubplot:xlabel='survived', ylabel='count'>

# %%
sns.barplot(data=df,x="survived",y="fare", hue="who")  # Categorial + Numeric Variable
# Out:
# <AxesSubplot:xlabel='survived', ylabel='fare'>

# %%
sns.countplot(x="pclass",data=df)
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='count'>

# %% [markdown]
# # Data Distribution

# %%
sns.histplot(data=df,x="age", bins=30)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
df['age'].hist(bins=30, color='darkred',alpha=0.75)  # Only for Numeric variable
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=df, y="age", x="survived", hue="who")  # Categorical + Nueric Variable
# Out:
# <AxesSubplot:xlabel='survived', ylabel='age'>

# %% [markdown]
# # Doual Numeric

# %%
sns.scatterplot(x="age", y="fare", data=df, hue="pclass")
plt.ylim(0,300)
# Out:
# (0.0, 300.0)

# %%
sns.pairplot(df, hue='survived')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\PKC2023\day_13\eda_a_z.ipynb Cell 31 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/PKC2023/day_13/eda_a_z.ipynb#X42sZmlsZQ%3D%3D?line=0'>1</a> sns.pairplot(df, hue='survived')
#
# File c:\Users\Al HAfiz Enterprises\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# ...

# %% [markdown]
# # Stacked barchart/plot

# %%
df.groupby(['pclass','who'])['survived'].mean().unstack().plot(kind='bar',stacked=True)

# %% [markdown]
# # Assignment
# ## How to Change positions of xticks in matplot lib

# %%
sns.swarmplot(data=df, x="survived", y='age')

# %%
sns.swarmplot(data=df, x="survived", y='age', hue="who")

# %%
sns.catplot(x='pclass', y='fare',hue='embarked',kind='point', data=df)   # Point Point

# %% [markdown]
# # Relationship of 2 Numeric Variables

# %%
sns.lmplot(data=df[df['fare']<300], x="age", y='fare', hue="pclass")

# %%
sns.lmplot( data=df, x="age", y='fare', hue="pclass")
plt.ylim(0,300)
# Out:
# (0.0, 300.0)

# %% [markdown]
# # y pr fare ko < 300 py draw krwna hy

# %% [markdown]
# # how to add a column and age Group

# %%
sns.histplot(data=df, x='age')

# %%
df['age_groups'] = pd.cut(df['age'], [0,10,18,30,50,80], 
labels=['Kids', 'Child','Youth', 'Middle age',"Old"])

# %%
df.head()

# %%
df.columns

# %%
df.groupby("age_groups")["survived"].mean().plot(kind="bar")

# %%
df.groupby("age_groups")["fare"].mean().plot(kind="bar")

# %%
sns.pairplot(df, hue="survived", vars=['age','fare','pclass'])

# %%
df['family'] = pd.cut(df['age'], [0,10,18,30,50,80], 
labels=['Gill', 'Khan','Ghallo', 'Balouch',"Khokhar"])

# %%
df.head()

# %%
df.groupby("family")["survived"].mean().plot(kind="bar")

# %% [markdown]
# # Assignment Add Family Size Columns (family_size)
# # Hint 2 Columns (sibsp-parch)

# %%
class Family (object):
    def_init_(self, family_id, last_name, address, family_size):
        self.family_id = family_id
        self.last_name = last_name
        self.address = address
        self.family_size = family_size
