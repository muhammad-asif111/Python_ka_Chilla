# %%
import pandas as pd
import numpy as np

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range("20230701", periods = 6)
dates
# Out:
# DatetimeIndex(['2023-07-01', '2023-07-02', '2023-07-03', '2023-07-04',
#                '2023-07-05', '2023-07-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.rand(6, 4), index=dates, columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2023-07-01  0.656585  0.708820  0.430073  0.211586
# 2023-07-02  0.551241  0.082151  0.173042  0.956041
# 2023-07-03  0.631884  0.436473  0.250055  0.445625
# 2023-07-04  0.734601  0.274280  0.910546  0.541333
# 2023-07-05  0.045339  0.390206  0.432913  0.078628
# 2023-07-06  0.021176  0.324394  0.319154  0.420769

# %% [markdown]
# # Dictionary Start with {} that Key & its Value

# %%
dict = {'Ammar': 5.0, "Ali": 5.5}
dict
# Out:
# {'Ammar': 5.0, 'Ali': 5.5}

# %%
import pandas as pd
df2 = pd.DataFrame(
        {
            "A": 1.0,
            "B": pd.Timestamp("20230701"),
            "C": pd.Series(1, index=list(range(4)), dtype="float32"),
            "D": np.array([3] * 4, dtype="int32"),
            "E": pd.Categorical(["test", "train", "test", "train"]),
            "F": "foo",
        }
    )
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2023-07-01  1.0  3   test  foo
# 1  1.0 2023-07-01  1.0  3  train  foo
# 2  1.0 2023-07-01  1.0  3   test  foo
# 3  1.0 2023-07-01  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4 entries, 0 to 3
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       4 non-null      float64
#  1   B       4 non-null      datetime64[ns]
#  2   C       4 non-null      float32
#  3   D       4 non-null      int32
#  4   E       4 non-null      category
#  5   F       4 non-null      object
# dtypes: category(1), datetime64[ns](1), float32(1), float64(1), int32(1), object(1)
# memory usage: 288.0+ bytes

# %%
df.to_numpy()
# Out:
# array([[0.65658483, 0.70881967, 0.43007342, 0.21158603],
#        [0.55124144, 0.08215056, 0.1730421 , 0.95604063],
#        [0.6318839 , 0.43647262, 0.25005456, 0.44562455],
#        [0.73460079, 0.27427992, 0.91054623, 0.54133268],
#        [0.04533921, 0.39020559, 0.43291301, 0.07862751],
#        [0.02117625, 0.32439356, 0.31915417, 0.42076857]])

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2023-07-01  0.211586  0.430073  0.708820  0.656585
# 2023-07-02  0.956041  0.173042  0.082151  0.551241
# 2023-07-03  0.445625  0.250055  0.436473  0.631884
# 2023-07-04  0.541333  0.910546  0.274280  0.734601
# 2023-07-05  0.078628  0.432913  0.390206  0.045339
# 2023-07-06  0.420769  0.319154  0.324394  0.021176

# %%
df.sort_values(by="B")
# Out:
#                    A         B         C         D
# 2023-07-02  0.551241  0.082151  0.173042  0.956041
# 2023-07-04  0.734601  0.274280  0.910546  0.541333
# 2023-07-06  0.021176  0.324394  0.319154  0.420769
# 2023-07-05  0.045339  0.390206  0.432913  0.078628
# 2023-07-03  0.631884  0.436473  0.250055  0.445625
# 2023-07-01  0.656585  0.708820  0.430073  0.211586

# %% [markdown]
# # Getting

# %%
df
# Out:
#                    A         B         C         D
# 2023-07-01  0.656585  0.708820  0.430073  0.211586
# 2023-07-02  0.551241  0.082151  0.173042  0.956041
# 2023-07-03  0.631884  0.436473  0.250055  0.445625
# 2023-07-04  0.734601  0.274280  0.910546  0.541333
# 2023-07-05  0.045339  0.390206  0.432913  0.078628
# 2023-07-06  0.021176  0.324394  0.319154  0.420769

# %%
df["A"]
# Out:
# 2023-07-01    0.656585
# 2023-07-02    0.551241
# 2023-07-03    0.631884
# 2023-07-04    0.734601
# 2023-07-05    0.045339
# 2023-07-06    0.021176
# Freq: D, Name: A, dtype: float64

# %%
df[['A', 'B']]
# Out:
#                    A         B
# 2023-07-01  0.656585  0.708820
# 2023-07-02  0.551241  0.082151
# 2023-07-03  0.631884  0.436473
# 2023-07-04  0.734601  0.274280
# 2023-07-05  0.045339  0.390206
# 2023-07-06  0.021176  0.324394

# %% [markdown]
# # Indexes

# %%
df
# Out:
#                    A         B         C         D
# 2023-07-01  0.656585  0.708820  0.430073  0.211586
# 2023-07-02  0.551241  0.082151  0.173042  0.956041
# 2023-07-03  0.631884  0.436473  0.250055  0.445625
# 2023-07-04  0.734601  0.274280  0.910546  0.541333
# 2023-07-05  0.045339  0.390206  0.432913  0.078628
# 2023-07-06  0.021176  0.324394  0.319154  0.420769

# %%
df.iloc[0 : 2, 0 : 3]
# Out:
#                    A         B         C
# 2023-07-01  0.656585  0.708820  0.430073
# 2023-07-02  0.551241  0.082151  0.173042

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.loc[:, ["A", "B"]]
# Out:
#                    A         B
# 2023-07-01  0.656585  0.708820
# 2023-07-02  0.551241  0.082151
# 2023-07-03  0.631884  0.436473
# 2023-07-04  0.734601  0.274280
# 2023-07-05  0.045339  0.390206
# 2023-07-06  0.021176  0.324394

# %%
df.iloc[3]
# Out:
# A    0.734601
# B    0.274280
# C    0.910546
# D    0.541333
# Name: 2023-07-04 00:00:00, dtype: float64

# %%
import seaborn as sns
kashti = sns.load_dataset("titanic")
kashti
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
kashti.sample(100)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 161         1       2  female  40.0      0      0   15.7500        S  Second
# 581         1       1  female  39.0      1      1  110.8833        C   First
# 726         1       2  female  30.0      3      0   21.0000        S  Second
# 475         0       1    male   NaN      0      0   52.0000        S   First
# 482         0       3    male  50.0      0      0    8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...       ...      ...     ...
# 391         1       3    male  21.0      0      0    7.7958        S   Third
# 472         1       2  female  33.0      1      2   27.7500        S  Second
# 464         0       3    male   NaN      0      0    8.0500        S   Third
# 598         0       3    male   NaN      0      0    7.2250        C   Third
# 371         0       3    male  18.0      1      0    6.4958        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# 161  woman       False  NaN  Southampton   yes   True
# 581  woman       False    C    Cherbourg   yes  False
# 726  woman       False  NaN  Southampton   yes  False
# 475    man        True    A  Southampton    no   True
# 482    man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 391    man        True  NaN  Southampton   yes   True
# 472  woman       False  NaN  Southampton   yes  False
# 464    man        True  NaN  Southampton    no   True
# 598    man        True  NaN    Cherbourg    no   True
# 371    man        True  NaN  Southampton    no  False
#
# [100 rows x 15 columns]

# %% [markdown]
# # Filter data using canditional operator

# %%
kashti[kashti['fare'] < 5]
# Out:
#      survived  pclass   sex   age  sibsp  parch    fare embarked   class  who  \
# 179         0       3  male  36.0      0      0  0.0000        S   Third  man
# 263         0       1  male  40.0      0      0  0.0000        S   First  man
# 271         1       3  male  25.0      0      0  0.0000        S   Third  man
# 277         0       2  male   NaN      0      0  0.0000        S  Second  man
# 302         0       3  male  19.0      0      0  0.0000        S   Third  man
# 378         0       3  male  20.0      0      0  4.0125        C   Third  man
# 413         0       2  male   NaN      0      0  0.0000        S  Second  man
# 466         0       2  male   NaN      0      0  0.0000        S  Second  man
# 481         0       2  male   NaN      0      0  0.0000        S  Second  man
# 597         0       3  male  49.0      0      0  0.0000        S   Third  man
# 633         0       1  male   NaN      0      0  0.0000        S   First  man
# 674         0       2  male   NaN      0      0  0.0000        S  Second  man
# 732         0       2  male   NaN      0      0  0.0000        S  Second  man
# 806         0       1  male  39.0      0      0  0.0000        S   First  man
# 815         0       1  male   NaN      0      0  0.0000        S   First  man
# 822         0       1  male  38.0      0      0  0.0000        S   First  man
#
#      adult_male deck  embark_town alive  alone
# 179        True  NaN  Southampton    no   True
# 263        True    B  Southampton    no   True
# 271        True  NaN  Southampton   yes   True
# 277        True  NaN  Southampton    no   True
# 302        True  NaN  Southampton    no   True
# 378        True  NaN    Cherbourg    no   True
# 413        True  NaN  Southampton    no   True
# 466        True  NaN  Southampton    no   True
# 481        True  NaN  Southampton    no   True
# 597        True  NaN  Southampton    no   True
# 633        True  NaN  Southampton    no   True
# 674        True  NaN  Southampton    no   True
# 732        True  NaN  Southampton    no   True
# 806        True    A  Southampton    no   True
# 815        True    B  Southampton    no   True
# 822        True  NaN  Southampton    no   True
