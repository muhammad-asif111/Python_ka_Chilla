# %% [markdown]
# # Ploting in Python by Dr. Muhammad Asif

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
kashti = sns.load_dataset('titanic')

# %%
kashti
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
kashti.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
kashti.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
kashti.survived.value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
sns.countplot(x="survived", hue="sex", data=kashti)
# Out:
# <AxesSubplot:xlabel='survived', ylabel='count'>

# %%
# Scatter Plot
plt.scatter(x="age", y="fare", data=kashti)

# %%
sns.scatterplot(x="age", y="fare", hue="pclass", data=kashti)
# Out:
# <AxesSubplot:xlabel='age', ylabel='fare'>

# %%
sns.barplot(x="sex", y="fare", hue="pclass", data=kashti)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='fare'>

# %%
kashti.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
sns.pairplot(kashti)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Al HAfiz Enterprises\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\lib\histograms.py:351, in _unsigned_subtract(a, b)
#     350 try:
# --> 351     dt = signed_to_unsigned[dt.type]
#     352 except KeyError:
#
# KeyError: <class 'numpy.bool_'>
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# d:\PKC2023.1\day_11\data_visulization.ipynb Cell 12 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/PKC2023.1/day_11/data_visulization.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> sns.pairplot(kashti)
#
# File c:\Users\Al HAfiz Enterprises\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
# ...

# %%
kashti.hist(bins=10, figsize=(9,7),grid=False)
# Out:
# array([[<AxesSubplot:title={'center':'survived'}>,
#         <AxesSubplot:title={'center':'pclass'}>],
#        [<AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'sibsp'}>],
#        [<AxesSubplot:title={'center':'parch'}>,
#         <AxesSubplot:title={'center':'fare'}>]], dtype=object)

# %%
sns.boxplot(data=kashti,x="sex", y="fare", hue="pclass")
# Out:
# <AxesSubplot:xlabel='sex', ylabel='fare'>

# %%
sns.boxenplot(data=kashti, x="sex", y="fare", hue="class")
# Out:
# <AxesSubplot:xlabel='sex', ylabel='fare'>

# %%
g= sns.FacetGrid(kashti, hue="survived", col="pclass", margin_titles=True, palette= {1: "seagreen", 0: "gray"})
g=g.map(plt.scatter, "fare", "age", edgecolor="g").add_legend();

# %%
g= sns.FacetGrid(kashti, hue="survived", col="who", margin_titles=True, palette= {1: "seagreen", 0: "gray"})
g=g.map(plt.scatter, "fare", "age", edgecolor="g").add_legend();

# %%
sns.stripplot(data=kashti, x="sex", y="fare", hue="class")
# Out:
# <AxesSubplot:xlabel='sex', ylabel='fare'>

# %%
corr = kashti.corr()
plt.figure(figsize=(10,10))
sns.heatmap(corr)
plt.title("Heat Map of Kashit Data")
# Out:
# Text(0.5, 1.0, 'Heat Map of Kashit Data')

# %%
sns.violinplot(data=kashti, x="sex", y="fare", hue="class")
# Out:
# <AxesSubplot:xlabel='sex', ylabel='fare'>
